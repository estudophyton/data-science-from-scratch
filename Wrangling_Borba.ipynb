# %% [markdown]
# <a href="https://colab.research.google.com/github/estudophyton/data-science-from-scratch/blob/master/Wrangling_Borba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Primeiro carregaremos as Bibliotecas

# %%
import pandas as pd
import requests
import numpy as np
import sqlite3
import sqlalchemy as sq
pd.options.display.max_columns=20
pd.set_option('display.max_rows',1000)

# %% [markdown]
# ##Caregaremos a primeira Base de dados e faremos algumas analisares

# %%
df=pd.read_csv("/content/drive/MyDrive/w_data.csv", sep=";")
df.sort_values(by='ID').head(5)
# Out:
#         Workclass    fnlwgt  Capital Gain  Capital Loss  Hours per week  \
# 39866     Private  305319.0           0.0           0.0            50.0
# 501     Local-gov  114060.0           0.0           0.0            40.0
# 8         Private   45781.0       14084.0           0.0            50.0
# 37823     Private  103397.0           0.0           0.0            40.0
# 8733      Private  179953.0        2597.0           0.0            31.0
#
#           ID   Target
# 39866   3080    >50K.
# 501     7286    <=50K
# 8       7496     >50K
# 37823   9929   <=50K.
# 8733   17968    <=50K

# %%
df["ID"].value_counts().sort_values()
# Out:
# 49084         1
# 1927654       1
# 1791056       1
# 109140        1
# 143654        1
#              ..
# 597186815     1
# 735617153     1
# 1131807446    1
# 780865193     1
# 1344995623    1
# Name: ID, Length: 48843, dtype: int64

# %%
df1=pd.read_csv("/content/drive/MyDrive/p_data.csv", sep=";")
df1.sort_values(by='ID').head(5)
# Out:
#         Age      Sex     ID    Race         Country Education  Education-Num  \
# 39866  36.0     Male   3080   White   United-States   Masters           14.0
# 501    62.0     Male   7286   White   United-States   HS-grad            9.0
# 8      31.0   Female   7496   White   United-States   Masters           14.0
# 37823  44.0   Female   9929   White   United-States   HS-grad            9.0
# 8733   25.0   Female  17968   White   United-States   Masters           14.0
#
#             Marital Status     Relationship
# 39866   Married-civ-spouse          Husband
# 501     Married-civ-spouse          Husband
# 8            Never-married    Not-in-family
# 37823             Divorced   Other-relative
# 8733         Never-married        Own-child

# %%
df1["ID"].value_counts().sort_values()
# Out:
# 49084        1
# 264164       1
# 1927654      1
# 1791056      1
# 109140       1
#             ..
# 159940648    1
# 597186815    1
# 735617153    1
# 343400423    1
# 161771296    1
# Name: ID, Length: 48842, dtype: int64

# %% [markdown]
# #UNINDO AS DUAS BASES DE DADOS

# %%
merged_df = pd.merge(df, df1, on='ID', how='inner')
merged_df
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48837            Private  245211.0           0.0           0.0
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
#
#        Hours per week          ID   Target   Age      Sex  \
# 0                40.0       49084    <=50K  39.0     Male
# 1                13.0       68553    <=50K  50.0     Male
# ...

# %%
merged_df["ID"].value_counts().sort_values()
# Out:
# 49084        1
# 264164       1
# 1927654      1
# 1791056      1
# 109140       1
#             ..
# 159940648    1
# 597186815    1
# 735617153    1
# 343400423    1
# 161771296    1
# Name: ID, Length: 48842, dtype: int64

# %% [markdown]
# QUANTOS ID TÊM EM COMUM? 48842

# %%
df.ID.nunique(), df1.ID.nunique(), merged_df.ID.nunique()
# Out:
# (48843, 48842, 48842)

# %%
merged_df.Target.value_counts()
# Out:
#  <=50K     24720
#  <=50K.    12435
#  >50K       7841
#  >50K.      3845
# Name: Target, dtype: int64

# %%
merged_df['Target'] = merged_df['Target'].str.strip()  # Remove espaços em branco
merged_df['Target'] = merged_df['Target'].replace({'>50K.': '>50K','<=50K.': '<=50K'})

# %%
merged_df.Target.value_counts()
# Out:
# <=50K    37155
# >50K     11686
# Name: Target, dtype: int64

# %%
merged_df
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48837            Private  245211.0           0.0           0.0
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
#
#        Hours per week          ID Target   Age      Sex                 Race  \
# 0                40.0       49084  <=50K  39.0     Male                White
# ...

# %%
filtered_df = merged_df[(merged_df['Target'] == '<=50K') & (merged_df['Sex'] == 'Male')]
filtered_df
# Out:
# Empty DataFrame
# Columns: [Workclass, fnlwgt, Capital Gain, Capital Loss, Hours per week, ID, Target, Age, Sex, Race, Country, Education, Education-Num, Marital Status, Relationship]
# Index: []
